# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# წავიკითხოთ csv
file_path = 'Earthquakes_database.csv'
earthquakes_df = pd.read_csv(file_path)

# გავყოთ "Date" სვეტი "Year", "Month", and "Day" სვეტებად
earthquakes_df[['Month', 'Day', 'Year']] = earthquakes_df['Date'].str.split('/', expand=True)

# გარდავქმნათ "Date" სვეტი
earthquakes_df['Date'] = pd.to_datetime(earthquakes_df['Date'], format='mixed', utc=True)


threshold = len(earthquakes_df) * 0.5
cleaned_df = earthquakes_df.dropna(thresh=threshold, axis=1)


print(cleaned_df.head())
print(cleaned_df.info())
# Out:
#                        Date      Time  Latitude  Longitude        Type  Depth  \
# 0 1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  Earthquake  131.6
# 1 1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352  Earthquake   80.0
# 2 1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972  Earthquake   20.0
# 3 1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557  Earthquake   15.0
# 4 1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427  Earthquake   15.0
#
#    Magnitude Magnitude Type  Root Mean Square            ID  Source  \
# 0        6.0             MW               NaN  ISCGEM860706  ISCGEM
# 1        5.8             MW               NaN  ISCGEM860737  ISCGEM
# 2        6.2             MW               NaN  ISCGEM860762  ISCGEM
# 3        5.8             MW               NaN  ISCGEM860856  ISCGEM
# 4        5.8             MW               NaN  ISCGEM860890  ISCGEM
#
#   Location Source Magnitude Source     Status Month Day  Year
# 0          ISCGEM           ISCGEM  Automatic     1   2  1965
# 1          ISCGEM           ISCGEM  Automatic     1   4  1965
# 2          ISCGEM           ISCGEM  Automatic     1   5  1965
# 3          ISCGEM           ISCGEM  Automatic     1   8  1965
# 4          ISCGEM           ISCGEM  Automatic     1   9  1965
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              23412 non-null  datetime64[ns, UTC]
#  1   Time              23412 non-null  object
#  2   Latitude          23412 non-null  float64
#  3   Longitude         23412 non-null  float64
#  4   Type              23412 non-null  object
#  5   Depth             23412 non-null  float64
#  6   Magnitude         23412 non-null  float64
#  7   Magnitude Type    23409 non-null  object
#  8   Root Mean Square  17352 non-null  float64
#  9   ID                23412 non-null  object
#  10  Source            23412 non-null  object
#  11  Location Source   23412 non-null  object
#  12  Magnitude Source  23412 non-null  object
#  13  Status            23412 non-null  object
#  14  Month             23412 non-null  object
#  15  Day               23409 non-null  object
#  16  Year              23409 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(5), object(11)
# memory usage: 3.0+ MB
# None

# %%
earthquakes_df
# Out:
#                            Date      Time  Latitude  Longitude        Type  \
# 0     1965-01-02 00:00:00+00:00  13:44:18   19.2460   145.6160  Earthquake
# 1     1965-01-04 00:00:00+00:00  11:29:49    1.8630   127.3520  Earthquake
# 2     1965-01-05 00:00:00+00:00  18:05:58  -20.5790  -173.9720  Earthquake
# 3     1965-01-08 00:00:00+00:00  18:49:43  -59.0760   -23.5570  Earthquake
# 4     1965-01-09 00:00:00+00:00  13:32:50   11.9380   126.4270  Earthquake
# ...                         ...       ...       ...        ...         ...
# 23407 2016-12-28 00:00:00+00:00   8:22:12   38.3917  -118.8941  Earthquake
# 23408 2016-12-28 00:00:00+00:00   9:13:47   38.3777  -118.8957  Earthquake
# 23409 2016-12-28 00:00:00+00:00  12:38:51   36.9179   140.4262  Earthquake
# 23410 2016-12-29 00:00:00+00:00  22:30:19   -9.0283   118.6639  Earthquake
# 23411 2016-12-30 00:00:00+00:00  20:08:28   37.3973   141.4103  Earthquake
#
#         Depth  Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 0      131.60          NaN                     NaN        6.0             MW
# 1       80.00          NaN                     NaN        5.8             MW
# 2       20.00          NaN                     NaN        6.2             MW
# 3       15.00          NaN                     NaN        5.8             MW
# 4       15.00          NaN                     NaN        5.8             MW
# ...       ...          ...                     ...        ...            ...
# 23407   12.30          1.2                    40.0        5.6             ML
# 23408    8.80          2.0                    33.0        5.5             ML
# 23409   10.00          1.8                     NaN        5.9            MWW
# 23410   79.00          1.8                     NaN        6.3            MWW
# 23411   11.94          2.2                     NaN        5.5             MB
#
#        ...  Horizontal Error  Root Mean Square            ID  Source  \
# 0      ...               NaN               NaN  ISCGEM860706  ISCGEM
# 1      ...               NaN               NaN  ISCGEM860737  ISCGEM
# 2      ...               NaN               NaN  ISCGEM860762  ISCGEM
# 3      ...               NaN               NaN  ISCGEM860856  ISCGEM
# 4      ...               NaN               NaN  ISCGEM860890  ISCGEM
# ...    ...               ...               ...           ...     ...
# 23407  ...               NaN            0.1898    NN00570710      NN
# 23408  ...               NaN            0.2187    NN00570744      NN
# 23409  ...               4.8            1.5200    US10007NAF      US
# 23410  ...               6.0            1.4300    US10007NL0      US
# 23411  ...               4.5            0.9100    US10007NTD      US
#
#        Location Source  Magnitude Source     Status Month Day  Year
# 0               ISCGEM            ISCGEM  Automatic     1   2  1965
# 1               ISCGEM            ISCGEM  Automatic     1   4  1965
# 2               ISCGEM            ISCGEM  Automatic     1   5  1965
# 3               ISCGEM            ISCGEM  Automatic     1   8  1965
# 4               ISCGEM            ISCGEM  Automatic     1   9  1965
# ...                ...               ...        ...   ...  ..   ...
# 23407               NN                NN   Reviewed    12  28  2016
# 23408               NN                NN   Reviewed    12  28  2016
# 23409               US                US   Reviewed    12  28  2016
# 23410               US                US   Reviewed    12  29  2016
# 23411               US                US   Reviewed    12  30  2016
#
# [23412 rows x 24 columns]

# %%
bins = [0, 4, 6, 10]
labels = ['Low', 'Medium', 'High']

# cut() ფუნქციით ვქმნით კატეგორიებს "Magnitude" სვეტისთვის
earthquakes_df['Magnitude_Category'] = pd.cut(earthquakes_df['Magnitude'], bins=bins, labels=labels, include_lowest=True)

print(earthquakes_df.head())
# Out:
#                        Date      Time  Latitude  Longitude        Type  Depth  \
# 0 1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  Earthquake  131.6
# 1 1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352  Earthquake   80.0
# 2 1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972  Earthquake   20.0
# 3 1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557  Earthquake   15.0
# 4 1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427  Earthquake   15.0
#
#    Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0          NaN                     NaN        6.0             MW  ...
# 1          NaN                     NaN        5.8             MW  ...
# 2          NaN                     NaN        6.2             MW  ...
# 3          NaN                     NaN        5.8             MW  ...
# 4          NaN                     NaN        5.8             MW  ...
#
#    Root Mean Square            ID  Source  Location Source  Magnitude Source  \
# 0               NaN  ISCGEM860706  ISCGEM           ISCGEM            ISCGEM
# 1               NaN  ISCGEM860737  ISCGEM           ISCGEM            ISCGEM
# 2               NaN  ISCGEM860762  ISCGEM           ISCGEM            ISCGEM
# 3               NaN  ISCGEM860856  ISCGEM           ISCGEM            ISCGEM
# 4               NaN  ISCGEM860890  ISCGEM           ISCGEM            ISCGEM
#
#       Status Month Day  Year Magnitude_Category
# 0  Automatic     1   2  1965             Medium
# 1  Automatic     1   4  1965             Medium
# 2  Automatic     1   5  1965               High
# 3  Automatic     1   8  1965             Medium
# 4  Automatic     1   9  1965             Medium
#
# [5 rows x 25 columns]

# %%
earthquakes_df
# Out:
#                            Date      Time  Latitude  Longitude        Type  \
# 0     1965-01-02 00:00:00+00:00  13:44:18   19.2460   145.6160  Earthquake
# 1     1965-01-04 00:00:00+00:00  11:29:49    1.8630   127.3520  Earthquake
# 2     1965-01-05 00:00:00+00:00  18:05:58  -20.5790  -173.9720  Earthquake
# 3     1965-01-08 00:00:00+00:00  18:49:43  -59.0760   -23.5570  Earthquake
# 4     1965-01-09 00:00:00+00:00  13:32:50   11.9380   126.4270  Earthquake
# ...                         ...       ...       ...        ...         ...
# 23407 2016-12-28 00:00:00+00:00   8:22:12   38.3917  -118.8941  Earthquake
# 23408 2016-12-28 00:00:00+00:00   9:13:47   38.3777  -118.8957  Earthquake
# 23409 2016-12-28 00:00:00+00:00  12:38:51   36.9179   140.4262  Earthquake
# 23410 2016-12-29 00:00:00+00:00  22:30:19   -9.0283   118.6639  Earthquake
# 23411 2016-12-30 00:00:00+00:00  20:08:28   37.3973   141.4103  Earthquake
#
#         Depth  Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 0      131.60          NaN                     NaN        6.0             MW
# 1       80.00          NaN                     NaN        5.8             MW
# 2       20.00          NaN                     NaN        6.2             MW
# 3       15.00          NaN                     NaN        5.8             MW
# 4       15.00          NaN                     NaN        5.8             MW
# ...       ...          ...                     ...        ...            ...
# 23407   12.30          1.2                    40.0        5.6             ML
# 23408    8.80          2.0                    33.0        5.5             ML
# 23409   10.00          1.8                     NaN        5.9            MWW
# 23410   79.00          1.8                     NaN        6.3            MWW
# 23411   11.94          2.2                     NaN        5.5             MB
#
#        ...  Root Mean Square            ID  Source  Location Source  \
# 0      ...               NaN  ISCGEM860706  ISCGEM           ISCGEM
# 1      ...               NaN  ISCGEM860737  ISCGEM           ISCGEM
# 2      ...               NaN  ISCGEM860762  ISCGEM           ISCGEM
# 3      ...               NaN  ISCGEM860856  ISCGEM           ISCGEM
# 4      ...               NaN  ISCGEM860890  ISCGEM           ISCGEM
# ...    ...               ...           ...     ...              ...
# 23407  ...            0.1898    NN00570710      NN               NN
# 23408  ...            0.2187    NN00570744      NN               NN
# 23409  ...            1.5200    US10007NAF      US               US
# 23410  ...            1.4300    US10007NL0      US               US
# 23411  ...            0.9100    US10007NTD      US               US
#
#        Magnitude Source     Status Month Day  Year Magnitude_Category
# 0                ISCGEM  Automatic     1   2  1965             Medium
# 1                ISCGEM  Automatic     1   4  1965             Medium
# 2                ISCGEM  Automatic     1   5  1965               High
# 3                ISCGEM  Automatic     1   8  1965             Medium
# 4                ISCGEM  Automatic     1   9  1965             Medium
# ...                 ...        ...   ...  ..   ...                ...
# 23407                NN   Reviewed    12  28  2016             Medium
# 23408                NN   Reviewed    12  28  2016             Medium
# 23409                US   Reviewed    12  28  2016             Medium
# 23410                US   Reviewed    12  29  2016               High
# 23411                US   Reviewed    12  30  2016             Medium
#
# [23412 rows x 25 columns]

# %%
# melt() ფუნქციით გარდავქმნით დატაფრეიმს
melted_df = pd.melt(earthquakes_df, id_vars=['Date'], value_vars=['Magnitude'], 
                    var_name='Measurement', value_name='Value')


print("Melted DataFrame:")
print(melted_df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 2
#       1 # melt() ფუნქციით გარდავქმნით ბაზას wide-დან long-ფორმატზე
# ----> 2 melted_df = pd.melt(earthquakes_df, id_vars=['Date'], value_vars=['Magnitude'],
#       3                     var_name='Measurement', value_name='Value')
#       5 print("Melted DataFrame:")
#       6 print(melted_df.head())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\melt.py:69, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      67         missing = Index(com.flatten(id_vars)).difference(cols)
#      68         if not missing.empty:
# ---> 69             raise KeyError(
#      70                 "The following 'id_vars' are not present "
#      71                 f"in the DataFrame: {list(missing)}"
#      72             )
#      73 else:
#      74     id_vars = []
#
# KeyError: "The following 'id_vars' are not present in the DataFrame: ['Date']"

# %%
earthquakes_df
# Out:
#                            Date      Time  Latitude  Longitude        Type  \
# 0     1965-01-02 00:00:00+00:00  13:44:18   19.2460   145.6160  Earthquake
# 1     1965-01-04 00:00:00+00:00  11:29:49    1.8630   127.3520  Earthquake
# 2     1965-01-05 00:00:00+00:00  18:05:58  -20.5790  -173.9720  Earthquake
# 3     1965-01-08 00:00:00+00:00  18:49:43  -59.0760   -23.5570  Earthquake
# 4     1965-01-09 00:00:00+00:00  13:32:50   11.9380   126.4270  Earthquake
# ...                         ...       ...       ...        ...         ...
# 23407 2016-12-28 00:00:00+00:00   8:22:12   38.3917  -118.8941  Earthquake
# 23408 2016-12-28 00:00:00+00:00   9:13:47   38.3777  -118.8957  Earthquake
# 23409 2016-12-28 00:00:00+00:00  12:38:51   36.9179   140.4262  Earthquake
# 23410 2016-12-29 00:00:00+00:00  22:30:19   -9.0283   118.6639  Earthquake
# 23411 2016-12-30 00:00:00+00:00  20:08:28   37.3973   141.4103  Earthquake
#
#         Depth  Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 0      131.60          NaN                     NaN        6.0             MW
# 1       80.00          NaN                     NaN        5.8             MW
# 2       20.00          NaN                     NaN        6.2             MW
# 3       15.00          NaN                     NaN        5.8             MW
# 4       15.00          NaN                     NaN        5.8             MW
# ...       ...          ...                     ...        ...            ...
# 23407   12.30          1.2                    40.0        5.6             ML
# 23408    8.80          2.0                    33.0        5.5             ML
# 23409   10.00          1.8                     NaN        5.9            MWW
# 23410   79.00          1.8                     NaN        6.3            MWW
# 23411   11.94          2.2                     NaN        5.5             MB
#
#        ...  Root Mean Square            ID  Source  Location Source  \
# 0      ...               NaN  ISCGEM860706  ISCGEM           ISCGEM
# 1      ...               NaN  ISCGEM860737  ISCGEM           ISCGEM
# 2      ...               NaN  ISCGEM860762  ISCGEM           ISCGEM
# 3      ...               NaN  ISCGEM860856  ISCGEM           ISCGEM
# 4      ...               NaN  ISCGEM860890  ISCGEM           ISCGEM
# ...    ...               ...           ...     ...              ...
# 23407  ...            0.1898    NN00570710      NN               NN
# 23408  ...            0.2187    NN00570744      NN               NN
# 23409  ...            1.5200    US10007NAF      US               US
# 23410  ...            1.4300    US10007NL0      US               US
# 23411  ...            0.9100    US10007NTD      US               US
#
#        Magnitude Source     Status Month Day  Year Magnitude_Category
# 0                ISCGEM  Automatic     1   2  1965             Medium
# 1                ISCGEM  Automatic     1   4  1965             Medium
# 2                ISCGEM  Automatic     1   5  1965               High
# 3                ISCGEM  Automatic     1   8  1965             Medium
# 4                ISCGEM  Automatic     1   9  1965             Medium
# ...                 ...        ...   ...  ..   ...                ...
# 23407                NN   Reviewed    12  28  2016             Medium
# 23408                NN   Reviewed    12  28  2016             Medium
# 23409                US   Reviewed    12  28  2016             Medium
# 23410                US   Reviewed    12  29  2016               High
# 23411                US   Reviewed    12  30  2016             Medium
#
# [23412 rows x 25 columns]

# %%
# pivot_table() ფუნქციით შევქმნათ summary თეიბლი გამოვთვალოთ საშუალო მაგნიტუდა წელიწადში
earthquakes_df['Year'] = pd.to_datetime(earthquakes_df['Date']).dt.year
pivot_table_df = earthquakes_df.pivot_table(values='Magnitude', index='Year', aggfunc='mean')


print("\nPivot Table:")
print(pivot_table_df.head())
# Out:
# Pivot Table:
#       Magnitude
# Year
# 1965   6.014159
# 1966   6.040470
# 1967   6.003922
# 1968   6.078525
# 1969   6.009350

# %%
# 'Date'-ის გადაყვანა datetime ფორმატად 
earthquakes_df['Date'] = pd.to_datetime(earthquakes_df['Date'], format='%m/%d/%Y')
earthquakes_df['Year'] = earthquakes_df['Date'].dt.year

# %%
# ლაინ ჩარტი - მიწისძვრების რაოდენობა
plt.figure(figsize=(10, 6))
earthquakes_per_year = earthquakes_df['Year'].value_counts().sort_index()
plt.plot(earthquakes_per_year.index, earthquakes_per_year.values, marker='o')
plt.title('მიწისძვრების რაოდენობა')
plt.xlabel('წელი')
plt.ylabel('მიწისძვრების რაოდენობა')
plt.grid(True)
plt.show()

# %%
# ბარ ჩარტი - მიწისძვრების საშუალო მაგნიტუდა წლების მიხედვით
plt.figure(figsize=(10, 6))
avg_magnitude_per_year = earthquakes_df.groupby('Year')['Magnitude'].mean()
avg_magnitude_per_year.plot(kind='bar')
plt.title('მიწისძვრების საშუალო მაგნიტუდა წლების მიხედვით')
plt.xlabel('წელი')
plt.ylabel('საშუალო მაგნიტუდა')
plt.grid(True)
plt.show()

# %%
# სკატერ ჩარტი - სიღრმე vs მიწისძვრების მაგნიტუდა
plt.figure(figsize=(10, 6))
sns.scatterplot(data=earthquakes_df, x='Depth', y='Magnitude')
plt.title('სიღრმე vs მიწისძვრების მაგნიტუდა')
plt.xlabel('სიღრმე კილომეტრებში (km)')
plt.ylabel('მაგნიტუდა')
plt.grid(True)
plt.show()

# %%
# ჰისტოგრამა - მიწისძვრის მაგნიტუდები
plt.figure(figsize=(10, 6))
plt.hist(earthquakes_df['Magnitude'], bins=30, edgecolor='black')
plt.title('მიწისძვრის მაგნიტუდები')
plt.xlabel('მაგნიტუდა')
plt.ylabel('სიხშირე')
plt.grid(True)
plt.show()

# %%
# ვანიჭებთ 'Date' სვეტს ინდექსად
earthquakes_df.set_index('Date', inplace=True)

# %%
# მიწისძვრების რაოდენობა თვეში
earthquakes_per_month = earthquakes_df['Magnitude'].resample('M').count()
print("Number of earthquakes per month:")
print(earthquakes_per_month.head())
# Out:
# Number of earthquakes per month:
# Date
# 1965-01-31 00:00:00+00:00    13
# 1965-02-28 00:00:00+00:00    54
# 1965-03-31 00:00:00+00:00    38
# 1965-04-30 00:00:00+00:00    33
# 1965-05-31 00:00:00+00:00    22
# Freq: M, Name: Magnitude, dtype: int64

# %%
# მიწისძვრების საშუალო მაგნიტუდების გამოთვლა წელიწადში
avg_magnitude_per_year = earthquakes_df['Magnitude'].resample('A').mean()
print("\nAverage magnitude of earthquakes per year:")
print(avg_magnitude_per_year.head())
# Out:
# Average magnitude of earthquakes per year:
# Date
# 1965-12-31 00:00:00+00:00    6.014159
# 1966-12-31 00:00:00+00:00    6.040470
# 1967-12-31 00:00:00+00:00    6.003922
# 1968-12-31 00:00:00+00:00    6.078525
# 1969-12-31 00:00:00+00:00    6.009350
# Freq: A-DEC, Name: Magnitude, dtype: float64

# %%
earthquakes_df
# Out:
#                                Time  Latitude  Longitude        Type   Depth  \
# Date
# 1965-01-02 00:00:00+00:00  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1965-01-04 00:00:00+00:00  11:29:49    1.8630   127.3520  Earthquake   80.00
# 1965-01-05 00:00:00+00:00  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 1965-01-08 00:00:00+00:00  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 1965-01-09 00:00:00+00:00  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...                             ...       ...        ...         ...     ...
# 2016-12-28 00:00:00+00:00   8:22:12   38.3917  -118.8941  Earthquake   12.30
# 2016-12-28 00:00:00+00:00   9:13:47   38.3777  -118.8957  Earthquake    8.80
# 2016-12-28 00:00:00+00:00  12:38:51   36.9179   140.4262  Earthquake   10.00
# 2016-12-29 00:00:00+00:00  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 2016-12-30 00:00:00+00:00  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#                            Depth Error  Depth Seismic Stations  Magnitude  \
# Date
# 1965-01-02 00:00:00+00:00          NaN                     NaN        6.0
# 1965-01-04 00:00:00+00:00          NaN                     NaN        5.8
# 1965-01-05 00:00:00+00:00          NaN                     NaN        6.2
# 1965-01-08 00:00:00+00:00          NaN                     NaN        5.8
# 1965-01-09 00:00:00+00:00          NaN                     NaN        5.8
# ...                                ...                     ...        ...
# 2016-12-28 00:00:00+00:00          1.2                    40.0        5.6
# 2016-12-28 00:00:00+00:00          2.0                    33.0        5.5
# 2016-12-28 00:00:00+00:00          1.8                     NaN        5.9
# 2016-12-29 00:00:00+00:00          1.8                     NaN        6.3
# 2016-12-30 00:00:00+00:00          2.2                     NaN        5.5
#
#                           Magnitude Type  Magnitude Error  ...  \
# Date                                                       ...
# 1965-01-02 00:00:00+00:00             MW              NaN  ...
# 1965-01-04 00:00:00+00:00             MW              NaN  ...
# 1965-01-05 00:00:00+00:00             MW              NaN  ...
# 1965-01-08 00:00:00+00:00             MW              NaN  ...
# 1965-01-09 00:00:00+00:00             MW              NaN  ...
# ...                                  ...              ...  ...
# 2016-12-28 00:00:00+00:00             ML            0.320  ...
# 2016-12-28 00:00:00+00:00             ML            0.260  ...
# 2016-12-28 00:00:00+00:00            MWW              NaN  ...
# 2016-12-29 00:00:00+00:00            MWW              NaN  ...
# 2016-12-30 00:00:00+00:00             MB            0.029  ...
#
#                            Root Mean Square            ID  Source  \
# Date
# 1965-01-02 00:00:00+00:00               NaN  ISCGEM860706  ISCGEM
# 1965-01-04 00:00:00+00:00               NaN  ISCGEM860737  ISCGEM
# 1965-01-05 00:00:00+00:00               NaN  ISCGEM860762  ISCGEM
# 1965-01-08 00:00:00+00:00               NaN  ISCGEM860856  ISCGEM
# 1965-01-09 00:00:00+00:00               NaN  ISCGEM860890  ISCGEM
# ...                                     ...           ...     ...
# 2016-12-28 00:00:00+00:00            0.1898    NN00570710      NN
# 2016-12-28 00:00:00+00:00            0.2187    NN00570744      NN
# 2016-12-28 00:00:00+00:00            1.5200    US10007NAF      US
# 2016-12-29 00:00:00+00:00            1.4300    US10007NL0      US
# 2016-12-30 00:00:00+00:00            0.9100    US10007NTD      US
#
#                            Location Source  Magnitude Source     Status Month  \
# Date
# 1965-01-02 00:00:00+00:00           ISCGEM            ISCGEM  Automatic     1
# 1965-01-04 00:00:00+00:00           ISCGEM            ISCGEM  Automatic     1
# 1965-01-05 00:00:00+00:00           ISCGEM            ISCGEM  Automatic     1
# 1965-01-08 00:00:00+00:00           ISCGEM            ISCGEM  Automatic     1
# 1965-01-09 00:00:00+00:00           ISCGEM            ISCGEM  Automatic     1
# ...                                    ...               ...        ...   ...
# 2016-12-28 00:00:00+00:00               NN                NN   Reviewed    12
# 2016-12-28 00:00:00+00:00               NN                NN   Reviewed    12
# 2016-12-28 00:00:00+00:00               US                US   Reviewed    12
# 2016-12-29 00:00:00+00:00               US                US   Reviewed    12
# 2016-12-30 00:00:00+00:00               US                US   Reviewed    12
#
#                           Day  Year Magnitude_Category
# Date
# 1965-01-02 00:00:00+00:00   2  1965             Medium
# 1965-01-04 00:00:00+00:00   4  1965             Medium
# 1965-01-05 00:00:00+00:00   5  1965               High
# 1965-01-08 00:00:00+00:00   8  1965             Medium
# 1965-01-09 00:00:00+00:00   9  1965             Medium
# ...                        ..   ...                ...
# 2016-12-28 00:00:00+00:00  28  2016             Medium
# 2016-12-28 00:00:00+00:00  28  2016             Medium
# 2016-12-28 00:00:00+00:00  28  2016             Medium
# 2016-12-29 00:00:00+00:00  29  2016               High
# 2016-12-30 00:00:00+00:00  30  2016             Medium
#
# [23412 rows x 24 columns]
